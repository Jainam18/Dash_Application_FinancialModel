# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Creatives.xlsx')
df
# Out:
#                               Position  Number of employees  \
# 0                              Manager                    1
# 1                         Video editor                    1
# 2                Video editor(Interns)                    5
# 3      Contingency team(Video Editing)                    3
# 4                     Content designer                    1
# 5             Content designer(Intern)                    5
# 6  Contingency team(Content Designing)                    8
# 7                       Content writer                    1
# 8               Content writer(Intern)                    5
# 9    Contingency team(Content writing)                    4
#
#    Salary/month/employee  Salary/month  Salary/year/employee  Salary/year  \
# 0               27916.67      27916.67                335000       335000
# 1               20000.00      20000.00                240000       240000
# 2                1000.00       5000.00                 12000        60000
# ...

# %%
df.describe()
# Out:
#        Number of employees  Salary/month/employee  Salary/month  \
# count            10.000000              10.000000     10.000000
# mean              3.400000            8475.000000  10875.000000
# std               2.412928           10546.783885   8785.795688
# min               1.000000            1000.000000   3000.000000
# 25%               1.000000            1000.000000   5000.000000
# 50%               3.500000            1000.000000   6500.000000
# 75%               5.000000           17500.000000  17500.000000
# max               8.000000           27916.670000  27916.670000
#
#        Salary/year/employee    Salary/year       Month 1       Month 2  \
# count              10.00000      10.000000     10.000000     10.000000
# mean           101700.00000  130500.000000  10875.000000  10875.000000
# std            126561.40363  105429.544668   8785.825251   8785.825251
# min             12000.00000   36000.000000   3000.000000   3000.000000
# ...

# %%
num_features = [feature for feature in df.columns if df[feature].dtype!='O']
for feature in num_features:
    print(f"{feature} - {df[feature].sum()}")
# Out:
# Number of employees - 34
# Salary/month/employee - 84750.0
# Salary/month - 108750.0
# Salary/year/employee - 1017000
# Salary/year - 1305000
# Month 1 - 108750
# Month 2 - 108750
# Month 3 - 421250
# Month 4 - 421250
# Month 5 - 521000
# Month 6 - 601834
# Month 7 - 667750
# Month 8 - 748583
# Month 9 - 814500
# Month 10 - 895333
# Month 11 - 942250
# Month 12 - 961250
# Month 13 - 1042084
# Month 14 - 1089000
# Month 15 - 1141833
# Month 16 - 1160833
# Month 17 - 1188833
# Month 18 - 1235750
# Month 19 - 1288583
# Month 20 - 1307583
# Month 21 - 1382500
# Month 22 - 1416334
# Month 23 - 1435334
# Month 24 - 1454334

# %%
df['Month 12'][df['Position']=='Manager']
# Out:
# 0    195417
# Name: Month 12, dtype: int64

# %% [markdown]
# This analysis can be helpful in part where we can show after a particular number of months what is the salary and what is the total amount being spent on creatives dept
#
# Eg. For Month 12:
#
# Total Amount being spent on salary for creatives dept is 961250.
#
# and The Salary of Manger in month 12 is 195417.

# %% [markdown]
# Interactivity also can be added using component datepicker or rangeslider or input box where we have months from 1 to 24 and there is pie chart which visualizes for a month for the salary is divided for each position of creatives dept

# %%
df1 = pd.read_excel('HR.xlsx')
df1
# Out:
#      Position  Number of employees  Salary/month/employee  Salary/month  \
# 0  HR manager                    1               25000.00         25000
# 1   Recruiter                    3                9166.67         27500
#
#    Salary/year/employee  Salary/year  Month 1  Month 2  Month 3  Month 4  ...  \
# 0                300000       300000    25000    25000    25000    25000  ...
# 1                110000       330000    27500    27500    27500    27500  ...
#
#    Month 15  Month 16  Month 17  Month 18  Month 19  Month 20  Month 21  \
# 0     25000     25000     25000     25000     25000     25000     25000
# 1     27500     27500     27500     27500     27500     27500     27500
#
#    Month 22  Month 23  Month 24
# 0     25000     25000     25000
# 1     27500     27500     27500
#
# [2 rows x 30 columns]

# %%
for feature in num_features:
    print(f"{feature} - {df1[feature].sum()}")
# Out:
# Number of employees - 4
# Salary/month/employee - 34166.67
# Salary/month - 52500
# Salary/year/employee - 410000
# Salary/year - 630000
# Month 1 - 52500
# Month 2 - 52500
# Month 3 - 52500
# Month 4 - 52500
# Month 5 - 52500
# Month 6 - 52500
# Month 7 - 52500
# Month 8 - 52500
# Month 9 - 52500
# Month 10 - 52500
# Month 11 - 52500
# Month 12 - 52500
# Month 13 - 52500
# Month 14 - 52500
# Month 15 - 52500
# Month 16 - 52500
# Month 17 - 52500
# Month 18 - 52500
# Month 19 - 52500
# Month 20 - 52500
# Month 21 - 52500
# Month 22 - 52500
# Month 23 - 52500
# Month 24 - 52500

# %% [markdown]
# Here this is a problem that the salary amount is same for each year so there can the number will stay constant throughout

# %%
df3 = pd.read_excel('CombinedData.xlsx')
df3
# Out:
#                                Position  Number of employees  \
# 0                               Manager                    1
# 1                          Video editor                    1
# 2                 Video editor(Interns)                    5
# 3       Contingency team(Video Editing)                    3
# 4                      Content designer                    1
# 5              Content designer(Intern)                    5
# 6   Contingency team(Content Designing)                    8
# 7                        Content writer                    1
# 8                Content writer(Intern)                    5
# 9     Contingency team(Content writing)                    4
# 10                           HR manager                    1
# 11                            Recruiter                    3
#
#     Salary/month/employee  Salary/month  Salary/year/employee  Salary/year  \
# 0                27916.67      27916.67                335000       335000
# ...
